# %%
# %pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.5-cp39-abi3-win_amd64.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic>=2.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (2.13.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (2.4.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.24.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (1.78.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (0.24.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from build>=1.0.3->chromadb) (26.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: certifi in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.27.0->chromadb) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: flatbuffers in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.73.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.0->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-1.7.2-py3-none-any.whl.metadata (13 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading hf_xet-1.4.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: click>=8.2.1 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading chromadb-1.5.5-cp39-abi3-win_amd64.whl (21.9 MB)
#    ---------------------------------------- 0.0/21.9 MB ? eta -:--:--
#    ------------- -------------------------- 7.6/21.9 MB 40.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 12.8/21.9 MB 33.1 MB/s eta 0:00:01
#    --------------------------------- ------ 18.4/21.9 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------  21.8/21.9 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------- 21.9/21.9 MB 25.3 MB/s  0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.4.1-py3-none-any.whl (24 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 65.6 MB/s  0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp313-cp313-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.24.4-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------------------- ---------------- 7.3/12.6 MB 35.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 25.9 MB/s  0:00:00
# Using cached opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.73.0-py3-none-any.whl (297 kB)
# Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl (124 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp313-cp313-win_amd64.whl (35 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 68.8 MB/s  0:00:00
# Downloading huggingface_hub-1.7.2-py3-none-any.whl (618 kB)
#    ---------------------------------------- 0.0/618.0 kB ? eta -:--:--
#    ---------------------------------------- 618.0/618.0 kB 8.9 MB/s  0:00:00
# Downloading hf_xet-1.4.2-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------------------------- 3.7/3.7 MB 61.2 MB/s  0:00:00
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 38.1 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 15.0 MB/s  0:00:00
# Installing collected packages: pypika, mpmath, durationpy, zipp, tenacity, sympy, pyproject_hooks, pybase64, overrides, orjson, opentelemetry-proto, oauthlib, mmh3, importlib-resources, hf-xet, googleapis-common-protos, fsspec, filelock, bcrypt, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, onnxruntime, importlib-metadata, build, opentelemetry-api, kubernetes, opentelemetry-semantic-conventions, huggingface-hub, tokenizers, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/32 [pypika]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    - --------------------------------------  1/32 [mpmath]
#    --- ------------------------------------  3/32 [zipp]
#    ----- ----------------------------------  4/32 [tenacity]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    ------ ---------------------------------  5/32 [sympy]
#    -------- -------------------------------  7/32 [pybase64]
#    ----------- ----------------------------  9/32 [orjson]
#    ------------ --------------------------- 10/32 [opentelemetry-proto]
#    ------------- -------------------------- 11/32 [oauthlib]
#    ------------- -------------------------- 11/32 [oauthlib]
#    ------------- -------------------------- 11/32 [oauthlib]
#    ------------- -------------------------- 11/32 [oauthlib]
#    ------------- -------------------------- 11/32 [oauthlib]
#    ------------- -------------------------- 11/32 [oauthlib]
#    ---------------- ----------------------- 13/32 [importlib-resources]
#    ---------------- ----------------------- 13/32 [importlib-resources]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    ------------------ --------------------- 15/32 [googleapis-common-protos]
#    -------------------- ------------------- 16/32 [fsspec]
#    -------------------- ------------------- 16/32 [fsspec]
#    -------------------- ------------------- 16/32 [fsspec]
#    -------------------- ------------------- 16/32 [fsspec]
#    -------------------- ------------------- 16/32 [fsspec]
#    --------------------- ------------------ 17/32 [filelock]
#    ----------------------- ---------------- 19/32 [requests-oauthlib]
#    ---------------- ---------- 20/32 [opentelemetry-exporter-otlp-proto-common]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    -------------------------- ------------- 21/32 [onnxruntime]
#    --------------------------- ------------ 22/32 [importlib-metadata]
#    ---------------------------- ----------- 23/32 [build]
#    ------------------------------ --------- 24/32 [opentelemetry-api]
#    ------------------------------ --------- 24/32 [opentelemetry-api]
#    ------------------------------ --------- 24/32 [opentelemetry-api]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    ------------------------------- -------- 25/32 [kubernetes]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 26/32 [opentelemetry-semantic-conventions]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    --------------------------------- ------ 27/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [tokenizers]
#    ------------------------------------ --- 29/32 [opentelemetry-sdk]
#    ------------------------------------ --- 29/32 [opentelemetry-sdk]
#    ------------------------------------ --- 29/32 [opentelemetry-sdk]
#    ------------------------------------ --- 29/32 [opentelemetry-sdk]
#    --------------------------- - 30/32 [opentelemetry-exporter-otlp-proto-grpc]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    -------------------------------------- - 31/32 [chromadb]
#    ---------------------------------------- 32/32 [chromadb]
#
# Successfully installed bcrypt-5.0.0 build-1.4.1 chromadb-1.5.5 durationpy-0.10 filelock-3.25.2 fsspec-2026.2.0 googleapis-common-protos-1.73.0 hf-xet-1.4.2 huggingface-hub-1.7.2 importlib-metadata-8.7.1 importlib-resources-6.5.2 kubernetes-35.0.0 mmh3-5.2.1 mpmath-1.3.0 oauthlib-3.3.1 onnxruntime-1.24.4 opentelemetry-api-1.40.0 opentelemetry-exporter-otlp-proto-common-1.40.0 opentelemetry-exporter-otlp-proto-grpc-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 orjson-3.11.7 overrides-7.7.0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 sympy-1.14.0 tenacity-9.1.4 tokenizers-0.22.2 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb
client = chromadb.Client()
collection = client.create_collection(name="my_col")

# %%
collection.add(
    documents = [
        "AI is transforming the world",
        "Machine learning is a subset of AI",
        "Deep learning uses neural networks"
    ],
    ids=["1", "2", "3"]
)
# Out:
# C:\Users\keval\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:09<00:00, 8.71MiB/s]

# %%
res = collection.query(
    query_texts = ["What is AI?"],
    n_results=1
)
print(res)
# Out:
# {'ids': [['1']], 'embeddings': None, 'documents': [['AI is transforming the world']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None]], 'distances': [[0.6467617750167847]]}
