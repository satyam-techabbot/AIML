# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.9.3)
# Requirement already satisfied: click in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus = """Hi neurons, please activate. I need to get data and take action."""
print(corpus)
# Out:
# Hi neurons, please activate. I need to get data and take action.

# %% [markdown]
# # Tokenization

# %%
## sentence to para
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\keval\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\keval\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
documents = sent_tokenize(corpus, language='english')
documents
# Out:
# ['Hi neurons, please activate.', 'I need to get data and take action.']

# %%
for sentence in documents:
    print(sentence, '\n')
# Out:
# Hi neurons, please activate.
#
# I need to get data and take action.

# %%
## para/sentence to word
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hi',
#  'neurons',
#  ',',
#  'please',
#  'activate',
#  '.',
#  'I',
#  'need',
#  'to',
#  'get',
#  'data',
#  'and',
#  'take',
#  'action',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence), '\n')
# Out:
# ['Hi', 'neurons', ',', 'please', 'activate', '.']
#
# ['I', 'need', 'to', 'get', 'data', 'and', 'take', 'action', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hi',
#  'neurons',
#  ',',
#  'please',
#  'activate.',
#  'I',
#  'need',
#  'to',
#  'get',
#  'data',
#  'and',
#  'take',
#  'action',
#  '.']

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

## PorterStemmer
stemming=PorterStemmer()
for word in words:
    print(word+"---->"+stemming.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %%
## RegexpStemmer class
from nltk.stem import RegexpStemmer
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
## Snowball Stemmer

from nltk.stem import SnowballStemmer
snowballsstemmer=SnowballStemmer('english')
for word in words:
    print(word+"---->"+snowballsstemmer.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %% [markdown]
# # Wordnet Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer 
lemmatizer=WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\keval\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairly",pos='v'),lemmatizer.lemmatize("sportingly")
# Out:
# ('fairly', 'sportingly')
