# %%
# !python -m pip install requests
# Out:
# Requirement already satisfied: requests in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\keval\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2026.1.4)

# %%
import requests as rq
print(rq.__version__)
# Out:
# 2.32.5

# %%
# get requests
api_url = "https://jsonplaceholder.typicode.com/todos/1"
res = rq.get(api_url)
print(f"Response: {res.json()}")
print(f"\nResponse Status Code: {res.status_code}")
print(f"\nResponse header: {res.headers["Content-Type"]}")
# Out:
# Response: {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}
#
# Response Status Code: 200
#
# Response header: application/json; charset=utf-8

# %%
# post
api_url = "https://jsonplaceholder.typicode.com/todos/"
todo = {'userId': 1, 'title': 'Hello', 'completed': False}
res = rq.post(api_url, todo)
print(res.status_code)
print(res.json())
# Out:
# 201
# {'userId': '1', 'title': 'Hello', 'completed': 'False', 'id': 201}

# %%
# put
todo = {'userId': 154, 'title': 'Hello', 'completed': False}
api_url = "https://jsonplaceholder.typicode.com/todos/10"
res = rq.put(api_url, json=todo)
print(res.json())
print(res)
# Out:
# {'userId': 154, 'title': 'Hello', 'completed': False, 'id': 10}
# <Response [200]>

# %%
# patch
todo = {'completed': True}
res = rq.patch(api_url, json=todo)
print(res.json())
print(res)
# Out:
# {'userId': 1, 'id': 10, 'title': 'illo est ratione doloremque quia maiores aut', 'completed': True}
# <Response [200]>

# %%
# delete
res = rq.delete(api_url)
print(res.json())
print(res)
# Out:
# {}
# <Response [200]>
